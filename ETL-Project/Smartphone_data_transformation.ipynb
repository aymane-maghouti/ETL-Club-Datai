# %% [markdown]
# <h1 style="color: green; text-align: center">Smartphone Data Cleaning & Transformation </h1>
# <hr width: 5px>
# <h3>✍ written by : </h3>
# <p><b>Maghouti</b> Aymane <br><b></b> Data engineering Student at the national school of applied sciences of alhociema <b>ENSAH</b></p>
# <p style="text-align: right;"><b>23-fev | <span style="color: red;">2024</span></b></p>

# %%
import pandas as pd

# %%
df = pd.read_csv('raw_data/jumia_mobile_phone.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 brand model_name screen_size  ram   rom cams sim_type  battary  \
# 0           0  Oppo      A17k         6.56  3.0  64.0  NaN     Dual      0.0
# 1           1   NaN        NaN         NaN  NaN   NaN  NaN      NaN      NaN
# 2           2   NaN        NaN         NaN  NaN   NaN  NaN      NaN      NaN
# 3           3   NaN        NaN         NaN  NaN   NaN  NaN      NaN      NaN
# 4           4  Oppo      A17k         6.56  3.0  64.0  NaN     Dual      0.0
#
#    current_price  previous_price sale_percentage  product_rating  \
# 0           63.0           952.0             0.0             4.1
# 1            NaN             NaN             NaN             NaN
# 2            NaN             NaN             NaN             NaN
# 3            NaN             NaN             NaN             NaN
# 4           63.0           952.0             0.0             4.7
#
#               seller_name seller_score seller_followers  \
# ...

# %%
df.shape
# Out:
# (1957, 17)

# %%
df.isna().sum()
# Out:
# Unnamed: 0             0
# brand               1432
# model_name          1432
# screen_size         1464
# ram                 1474
# rom                 1474
# cams                1519
# sim_type            1432
# battary             1440
# current_price       1432
# previous_price      1432
# sale_percentage     1432
# product_rating      1432
# seller_name         1432
# seller_score        1432
# seller_followers    1432
# Reviews             1432
# dtype: int64

# %% [markdown]
# ### drop the NA value

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# brand               0
# model_name          0
# screen_size         0
# ram                 0
# rom                 0
# cams                0
# sim_type            0
# battary             0
# current_price       0
# previous_price      0
# sale_percentage     0
# product_rating      0
# seller_name         0
# seller_score        0
# seller_followers    0
# Reviews             0
# dtype: int64

# %%
df['brand'].unique()
# Out:
# array(['Tecno', 'Infinix', 'XIAOMI', 'Freeyond', 'Maxfone', 'Huawei',
#        'Nokia', 'Samsung', 'Oppo', 'Sowhat', 'Realme', 'Apple', 'Vivo',
#        'Gionee'], dtype=object)

# %%
df.shape
# Out:
# (389, 17)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#     Unnamed: 0    brand     model_name screen_size  ram    rom  \
# 9            9    Tecno  Spark 10 Pro          6.8  8.0  128.0
# 12          12  Infinix   Hot 30 Play         6.82  8.0  128.0
# 13          13   XIAOMI      Redmi A2         6.52  3.0   64.0
# 16          16    Tecno     Spark 10C          6.6  4.0  128.0
# 19          19  Infinix    Smart 7 HD          6.6  2.0   64.0
#
#                  cams sim_type  battary  current_price  previous_price  \
# 9   50MP + 2MP + 32MP     Dual   5000.0          104.0          2720.0
# 12         16MP + 8MP     Dual   6000.0           81.0          1564.0
# 13          8MP + 5MP     Dual   5000.0           52.0          1088.0
# 16         16MP + 8MP     Dual   5000.0           77.0          1768.0
# 19          8MP + 5MP     Dual   5000.0           50.0          1020.0
#
#    sale_percentage  product_rating             seller_name seller_score  \
# 9              43%             4.4                Minestar          86%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 9 to 1953
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        389 non-null    int64
#  1   brand             389 non-null    object
#  2   model_name        389 non-null    object
#  3   screen_size       389 non-null    object
#  4   ram               389 non-null    float64
#  5   rom               389 non-null    float64
#  6   cams              389 non-null    object
#  7   sim_type          389 non-null    object
#  8   battary           389 non-null    float64
#  9   current_price     389 non-null    float64
#  10  previous_price    389 non-null    float64
#  11  sale_percentage   389 non-null    object
#  12  product_rating    389 non-null    float64
#  13  seller_name       389 non-null    object
#  14  seller_score      389 non-null    object
#  15  seller_followers  389 non-null    object
# ...

# %% [markdown]
# ### Convert the type of some features to numeric type

# %%
df = df[df['screen_size'].apply(lambda x: x.isnumeric() or x.replace('.', '').isnumeric())]

# %%
df['screen_size'] = pd.to_numeric(df['screen_size'])
df['ram']=pd.to_numeric(df['ram'])
df['rom']=pd.to_numeric(df['rom'])
df['battary']=pd.to_numeric(df['battary'])
df['previous_price']=pd.to_numeric(df['previous_price'])
df['current_price']=pd.to_numeric(df['current_price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 388 entries, 9 to 1953
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        388 non-null    int64
#  1   brand             388 non-null    object
#  2   model_name        388 non-null    object
#  3   screen_size       388 non-null    float64
#  4   ram               388 non-null    float64
#  5   rom               388 non-null    float64
#  6   cams              388 non-null    object
#  7   sim_type          388 non-null    object
#  8   battary           388 non-null    float64
#  9   current_price     388 non-null    float64
#  10  previous_price    388 non-null    float64
#  11  sale_percentage   388 non-null    object
#  12  product_rating    388 non-null    float64
#  13  seller_name       388 non-null    object
#  14  seller_score      388 non-null    object
#  15  seller_followers  388 non-null    object
# ...

# %%
df.head()
# Out:
#     Unnamed: 0    brand     model_name  screen_size  ram    rom  \
# 9            9    Tecno  Spark 10 Pro          6.80  8.0  128.0
# 12          12  Infinix   Hot 30 Play          6.82  8.0  128.0
# 13          13   XIAOMI      Redmi A2          6.52  3.0   64.0
# 16          16    Tecno     Spark 10C          6.60  4.0  128.0
# 19          19  Infinix    Smart 7 HD          6.60  2.0   64.0
#
#                  cams sim_type  battary  current_price  previous_price  \
# 9   50MP + 2MP + 32MP     Dual   5000.0          104.0          2720.0
# 12         16MP + 8MP     Dual   6000.0           81.0          1564.0
# 13          8MP + 5MP     Dual   5000.0           52.0          1088.0
# 16         16MP + 8MP     Dual   5000.0           77.0          1768.0
# 19          8MP + 5MP     Dual   5000.0           50.0          1020.0
#
#    sale_percentage  product_rating             seller_name seller_score  \
# 9              43%             4.4                Minestar          86%
# ...

# %%
data = pd.DataFrame(df[['brand','screen_size','ram','rom','sim_type','battary','previous_price','current_price']])

# %%
data.head()
# Out:
#       brand  screen_size  ram    rom sim_type  battary  previous_price  \
# 9     Tecno         6.80  8.0  128.0     Dual   5000.0          2720.0
# 12  Infinix         6.82  8.0  128.0     Dual   6000.0          1564.0
# 13   XIAOMI         6.52  3.0   64.0     Dual   5000.0          1088.0
# 16    Tecno         6.60  4.0  128.0     Dual   5000.0          1768.0
# 19  Infinix         6.60  2.0   64.0     Dual   5000.0          1020.0
#
#     current_price
# 9           104.0
# 12           81.0
# 13           52.0
# 16           77.0
# 19           50.0

# %%
data.shape
# Out:
# (388, 8)

# %% [markdown]
# ### Adding a Mean Price Column

# %%
data['price'] = (data['current_price'] + data['previous_price']) / 2

# %%
data.head()
# Out:
#       brand  screen_size  ram    rom sim_type  battary  previous_price  \
# 9     Tecno         6.80  8.0  128.0     Dual   5000.0          2720.0
# 12  Infinix         6.82  8.0  128.0     Dual   6000.0          1564.0
# 13   XIAOMI         6.52  3.0   64.0     Dual   5000.0          1088.0
# 16    Tecno         6.60  4.0  128.0     Dual   5000.0          1768.0
# 19  Infinix         6.60  2.0   64.0     Dual   5000.0          1020.0
#
#     current_price   price
# 9           104.0  1412.0
# 12           81.0   822.5
# 13           52.0   570.0
# 16           77.0   922.5
# 19           50.0   535.0

# %%
data = pd.DataFrame(data[['brand','screen_size','ram','rom','sim_type','battary','price']])

# %%
data.head()
# Out:
#       brand  screen_size  ram    rom sim_type  battary   price
# 9     Tecno         6.80  8.0  128.0     Dual   5000.0  1412.0
# 12  Infinix         6.82  8.0  128.0     Dual   6000.0   822.5
# 13   XIAOMI         6.52  3.0   64.0     Dual   5000.0   570.0
# 16    Tecno         6.60  4.0  128.0     Dual   5000.0   922.5
# 19  Infinix         6.60  2.0   64.0     Dual   5000.0   535.0

# %% [markdown]
# ### save the dataframe as csv file

# %%
data.to_csv("cleaned_data/smartphone_Data.csv")
